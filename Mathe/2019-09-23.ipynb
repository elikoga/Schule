# %%
data = [[1830, 9428],
[1880,30100],
[1900,58102],
[1925,76678],
[1933,101188],
[1945,91603],
[1950,103276],
[1965,133117],
[1985,121204],
[2007,117247]]

# %%
var('a,b,c,d')
# Out:
# (a, b, c, d)

# %%
plot(points(data))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('a,b,c,d')
f(x)=a*x^3+b*x^2+c*x+d
fit = find_fit(data,f,solution_dict=True)
a = fit[a]
b = fit[b]
c = fit[c]
d = fit[d]
f(x)=f(x,a=a,b=b,c=c,d=d)
show(plot(f(x),(x,1830,2007))+plot(points(data)))
f(1975)
# Out:
# Graphics object consisting of 2 graphics primitives
# 123485.1162570715

# %%
var('a,b,c,d')
f(x)=a*x^2+b*x+c
fit = find_fit(data,f,solution_dict=True)
a = fit[a]
b = fit[b]
c = fit[c]
f(x)=f(x,a=a,b=b,c=c,d=d)
show(plot(f(x),(x,1830,2007))+plot(points(data)))
f(1975)
# Out:
# Graphics object consisting of 2 graphics primitives
# 114975.16273132898

# %%
var('a,b,c,d')
f(x)=a*x+b
fit = find_fit(data,f,solution_dict=True)
a = fit[a]
b = fit[b]
f(x)=f(x,a=a,b=b,c=c,d=d)
show(plot(f(x),(x,1830,2007))+plot(points(data)))
f(1975)
# Out:
# Graphics object consisting of 2 graphics primitives
# 115893.1205191419

# %%
solve(1/8*x^3-3/4*x^2==tan(degree))
